# %%
# %cd ..
# Out:
# C:\Users\kubak\Desktop\github\FuzzyClusteringAlgorithms
# C:\Users\kubak\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from libraries.tests.test_dataset import test_dataset
from libraries.plot_functions import plot_centroids_from_dict, plot_metrics_by_algorithm, plot_metrics_by_metrics, plot_metrics_by_dataset

# %%
output_list = []
output_list_name = []

# %% [markdown]
# ### Basic Motions

# %%
chunk_length_train = 100
chunk_length_test = 100
elements_in_class_train = 5
elements_in_class_test = 0
n_clusters = 50
n_classes = 4
dim = 6
m = 2
g_error = 0.05
injection = 0.0
dataset_name = 'BasicMotions'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
output_basic_motions = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train  = elements_in_class_train, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_basic_motions)
output_list_name.append(dataset_name)
# Out:
# C:\Users\kubak\Desktop\github\FuzzyClusteringAlgorithms\libraries\process_data.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(lambda x: pad_or_trim_list(x.tolist(), padding_length))
#   Algorytm biblioteczny FCM
# Czas wykonania: 2.330939292907715 sekund
#   Własna implementacja FCM
# Czas wykonania: 2.3168394565582275 sekund
#   Algorytm SSFCM
# Czas wykonania: 2.0716209411621094 sekund
#   KNN   k = 7
# Czas wykonania: 0.3137631416320801 sekund
#   KNN z 40% danymi treningowymi, k = 7
# Czas wykonania: 0.3012263774871826 sekund
#   SVM
# Czas wykonania: 0.517474889755249 sekund
# Local DISSFCM
# Processing: 100%|█████████████| 20/20 [00:03<00:00,  5.46it/s]
# Czas wykonania: 3.8738653659820557 sekund
# DISSFCM
# Processing: 100%|█████████████| 20/20 [00:03<00:00,  5.05it/s]
# Czas wykonania: 4.116902828216553 sekund
# IFCM
# Processing: 100%|█████████████| 20/20 [00:02<00:00,  8.18it/s]
# Czas wykonania: 2.5500712394714355 sekund
# Local IFCM
# Processing: 100%|█████████████| 20/20 [00:03<00:00,  6.44it/s]
# Czas wykonania: 3.255286931991577 sekund
# extending IFCM
# Processing:  95%|████████████▎| 19/20 [00:07<00:00,  2.68it/s]
# Czas wykonania: 7.3148252964019775 sekund
# ISSFCM
# Processing: 100%|█████████████| 20/20 [00:02<00:00,  7.07it/s]
# Czas wykonania: 2.974654197692871 sekund
# Local ISSFCM
# Processing: 100%|█████████████| 20/20 [00:03<00:00,  5.97it/s]
# Czas wykonania: 3.527829170227051 sekund
# Czas wykonania wszystkich algorytmów: 37.4845130443573 sekund

# %%
plot_centroids_from_dict(output_basic_motions)
# Out:
# ---------------------------------------------------------------
# AttributeError                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plot_centroids_from_dict(output_basic_motions)
#
# File ~\Desktop\github\FuzzyClusteringAlgorithms\libraries\plot_functions.py:259, in plot_centroids_from_dict(data_dict)
#     256 plt.figure()
#     257 plt.title("Centroidy dla różnych klastrów (z PCA dla wymiarów > 2)")
# --> 259 for name, values in data_dict.items():
#     260     centroids = np.array(values[2])  # Pobierz centroidy (trzeci element listy)
#     261     n_clusters, dim = centroids.shape
#
# AttributeError: 'tuple' object has no attribute 'items'

# %%
plot_metrics_by_dataset([output_basic_motions], [dataset_name])

# %% [markdown]
# ### Cricket

# %%
chunk_length_train = 1197
chunk_length_test = 1197
elements_in_class_train = 0
elements_in_class_test = 0
n_clusters = 24
n_classes = 12
dim = 6
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'Cricket'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
output_cricket = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train   = elements_in_class_train  , n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_cricket)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_cricket)

# %%
plot_metrics_by_dataset([output_cricket], [dataset_name])

# %% [markdown]
# ### EigenWorms

# %%
chunk_length_train = 128
chunk_length_test = 131
elements_in_class_train  = 0
elements_in_class_test = 0
n_clusters = 10
n_classes = 5
dim = 6
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'EigenWorms'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
#output_eigen_worms = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train   = elements_in_class_train  , n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
#output_list.append(output_cricket)
#output_list_name.append(dataset_name)

# %%
#plot_centroids_from_dict(output_eigen_worms)

# %% [markdown]
# ### ArticularyWordRecognition

# %%
chunk_length_train = 144
chunk_length_test = 144
elements_in_class_train = 2
elements_in_class_test = 0
n_classes = 25
n_clusters = n_classes * 2
dim = 9
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'ArticularyWordRecognition'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
output_articulary_word_recognition = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train  = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_articulary_word_recognition)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_articulary_word_recognition)

# %%
plot_metrics_by_dataset([output_articulary_word_recognition], [dataset_name])

# %% [markdown]
# ### AtrialFibrillation

# %%
chunk_length_train = 150
chunk_length_test = 150
elements_in_class_train   = 0
n_classes = 3
n_clusters = 6
dim = 2

m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'AtrialFibrillation'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
#output_atrial_fibrillation = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train   = elements_in_class_train  , n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
#output_list.append(output_atrial_fibrillation)
#output_list_name.append(dataset_name)

# %%
#plot_centroids_from_dict(output_atrial_fibrillation)

# %% [markdown]
# ### Epilepsy

# %%
chunk_length_train = 206
chunk_length_test = 206
elements_in_class_train = 2
elements_in_class_test = 0
n_classes = 4
n_clusters = n_classes * 2
dim = 3
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'Epilepsy'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
output_epilepsy = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train   = elements_in_class_train  , n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_epilepsy)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_epilepsy)

# %%
plot_metrics_by_dataset([output_epilepsy], [dataset_name])

# %% [markdown]
# ### ERing

# %%
chunk_length_train = 300
chunk_length_test = 270
elements_in_class_train   = 0
n_classes = 6
n_clusters = n_classes * 2
dim = 4

m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'ERing'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
#output_ering = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train   = elements_in_class_train  , n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
#output_list.append(output_ering)
#output_list_name.append(dataset_name)

# %%
#plot_centroids_from_dict(output_ering)

# %% [markdown]
# ### EthanolConcentration

# %%
chunk_length_train = 100
chunk_length_test = 100
elements_in_class_train = 2
elements_in_class_test = 0
n_classes = 4
n_clusters = n_classes * 2
dim = 3
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'EthanolConcentration'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False

# %%
output_ethanol = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_ethanol)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_ethanol)

# %%
plot_metrics_by_dataset([output_ethanol], [dataset_name])

# %% [markdown]
# ### Finger Movements

# %%
chunk_length_train = 300
chunk_length_test = 100
elements_in_class_train = 5
elements_in_class_test = 0
n_classes = 2
n_clusters = n_classes * 2
dim = 28
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'FingerMovements'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False

# %%
output_finger_movments = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_finger_movments)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_finger_movments)

# %%
plot_metrics_by_dataset([output_finger_movments], [dataset_name])

# %% [markdown]
# ### Handwriting

# %%
chunk_length_train = 152
chunk_length_test = 152
elements_in_class_train = 3
elements_in_class_test = 0
n_classes = 26
n_clusters = n_classes * 2
dim = 3
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'Handwriting'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False

# %%
output_handwriting = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_handwriting)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_handwriting)

# %%
plot_metrics_by_dataset([output_handwriting], [dataset_name])

# %% [markdown]
# ### Heartbeat

# %%
chunk_length_train = 405
chunk_length_test = 405
elements_in_class_train = 2
elements_in_class_test = 0
n_classes = 2
n_clusters = n_classes * 2
dim = 61
m = 2
g_error = 0.05
injection = 0.5
dataset_name = 'Heartbeat'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False

# %%
output_heartbeat = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_heartbeat)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_heartbeat)

# %%
plot_metrics_by_dataset([output_heartbeat], [dataset_name])

# %% [markdown]
# ### Libras

# %%
chunk_length_train = 100
chunk_length_test = 100
elements_in_class_train = 2
elements_in_class_test = 0
n_classes = 15
n_clusters = n_classes * 2
dim = 2
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'Libras'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False

# %%
output_libras = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_libras)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_libras)

# %%
plot_metrics_by_dataset([output_libras], [dataset_name])

# %% [markdown]
# ### MotorImagery

# %%
chunk_length_train = 300
chunk_length_test = 300
elements_in_class_train = 2
elements_in_class_test = 0
n_classes = 2
n_clusters = n_classes * 2
dim = 64
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'MotorImagery'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False

# %%
output_motor_imagery = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_motor_imagery)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_motor_imagery)

# %%
plot_metrics_by_dataset([output_motor_imagery], [dataset_name])

# %% [markdown]
# ### NATOPS

# %%
chunk_length_train = 51
chunk_length_test = 51
elements_in_class_train = 2
elements_in_class_test = 0
n_classes = 6
n_clusters = n_classes * 2
dim = 24
m = 2
g_error = 0.05
injection = 1.0
dataset_name = 'NATOPS'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False

# %%
output_natops = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, elements_in_class_train = elements_in_class_train, elements_in_class_test = elements_in_class_test, n_clusters = n_clusters, n_classes = n_classes, dim = dim,  m = m, error = g_error, injection = injection, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
output_list.append(output_natops)
output_list_name.append(dataset_name)

# %%
plot_centroids_from_dict(output_natops)

# %%
plot_metrics_by_dataset([output_natops], [dataset_name])

# %% [markdown]
# ### Porównanie wszystkich dataset'ów

# %%
plot_metrics_by_dataset(output_list, output_list_name)

# %%
plot_metrics_by_metrics(output_list, output_list_name)

# %%
plot_metrics_by_algorithm(output_list, output_list_name)

# %%
# %cd ..
# Out:
# C:\Users\kubak\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# C:\Users\kubak\Desktop\github\FuzzyClusteringAlgorithms

# %%
from libraries.tests.test_dataset import test_dataset

# %% [markdown]
# ### Basic Motions

# %%
chunk_length_train = 400
chunk_length_test = 100
std_div = 0
n_clusters = 8
n_classes = 4
dim = 6
injection = 1.0
m = 2
g_error = 0.05
stratify_percantage = 1.0
dataset_name = 'BasicMotions'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
output_basic_motions = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, std_div = std_div, n_clusters = n_clusters, n_classes = n_classes, dim = dim, injection = injection, m = m, error = g_error, stratify_percantage = stratify_percantage, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data,  print_statistics_incremental_data = print_statistics_incremental_data)
# Out:
#   Algorytm biblioteczny FCM
# Czas wykonania: 0.43399786949157715 sekund
#   Własna implementacja FCM
# Czas wykonania: 0.3540329933166504 sekund
#   Algorytm SSFCM
# Czas wykonania: 0.39800071716308594 sekund
#   KNN   k = 7
# Czas wykonania: 0.7750265598297119 sekund
#   KNN z 40% danymi treningowymi, k = 7
# Czas wykonania: 0.70497727394104 sekund
# Local DISSFCM
# Processing: 100%|███████████████████████████| 12/12 [00:08<00:00,  1.50it/s]
# Czas wykonania: 8.299762487411499 sekund
# DISSFCM
# Processing: 100%|███████████████████████████| 12/12 [00:03<00:00,  3.35it/s]
# Czas wykonania: 3.8779242038726807 sekund
# IFCM
# Processing: 100%|███████████████████████████| 12/12 [00:04<00:00,  2.95it/s]
# Czas wykonania: 4.333332300186157 sekund
# Local IFCM
# Processing: 100%|███████████████████████████| 12/12 [00:03<00:00,  3.29it/s]
# Czas wykonania: 4.012001276016235 sekund
# extending IFCM
# Processing:  92%|████████████████████████▊  | 11/12 [00:03<00:00,  3.36it/s]
# Czas wykonania: 3.8572988510131836 sekund
# ISSFCM
# Processing: 100%|███████████████████████████| 12/12 [00:03<00:00,  3.16it/s]
# Czas wykonania: 4.097336053848267 sekund
# Local ISSFCM
# Processing: 100%|███████████████████████████| 12/12 [00:04<00:00,  2.96it/s]
# Czas wykonania: 4.347156047821045 sekund
# Czas wykonania wszystkich algorytmów: 36.369333028793335 sekund

# %% [markdown]
# ### Cricket

# %%
chunk_length_train = 300
chunk_length_test = 300
std_div = 0
n_clusters = 24
n_classes = 12
dim = 6
injection = 1.0
m = 2
g_error = 0.05
stratify_percantage = 0.1
dataset_name = 'Cricket'
visualise_processed_data = False
visualise_non_incremental_data = False
visualise_incremental_data = False
print_statistics_incremental_data = False
visualise_output_of_incremental_data = False

# %%
output_cricket = test_dataset(chunk_length_train = chunk_length_train, chunk_length_test = chunk_length_test, std_div = std_div, n_clusters = n_clusters, n_classes = n_classes, dim = dim, injection = injection, m = m, error = g_error, stratify_percantage = stratify_percantage, dataset_name = dataset_name, visualise_processed_data = visualise_processed_data, visualise_non_incremental_data = visualise_non_incremental_data, visualise_incremental_data = visualise_incremental_data, visualise_output_of_incremental_data = visualise_output_of_incremental_data ,  print_statistics_incremental_data = print_statistics_incremental_data)
# Out:
#   Algorytm biblioteczny FCM
# Czas wykonania: 5.798301696777344 sekund
#   Własna implementacja FCM
# Czas wykonania: 1.577181100845337 sekund
#   Algorytm SSFCM
# Czas wykonania: 1.6720175743103027 sekund
#   KNN   k = 7
# Czas wykonania: 0.740210771560669 sekund
#   KNN z 40% danymi treningowymi, k = 7
# Czas wykonania: 0.5554032325744629 sekund
# Local DISSFCM
# Processing: 100%|███████████████████████████| 48/48 [01:09<00:00,  1.45s/it]
# Czas wykonania: 69.58568263053894 sekund
# DISSFCM
# Processing: 100%|███████████████████████████| 48/48 [00:04<00:00,  9.87it/s]
# Czas wykonania: 4.926002740859985 sekund
# IFCM
# Processing: 100%|███████████████████████████| 48/48 [00:02<00:00, 17.16it/s]
# Czas wykonania: 2.84846568107605 sekund
# Local IFCM
# Processing: 100%|███████████████████████████| 48/48 [00:02<00:00, 20.38it/s]
# Czas wykonania: 2.4082767963409424 sekund
# extending IFCM
# Processing:  98%|██████████████████████████▍| 47/48 [00:04<00:00, 11.42it/s]
# Czas wykonania: 4.225519180297852 sekund
# ISSFCM
# Processing: 100%|███████████████████████████| 48/48 [00:03<00:00, 15.51it/s]
# Czas wykonania: 3.1549978256225586 sekund
# Local ISSFCM
# Processing: 100%|███████████████████████████| 48/48 [00:02<00:00, 19.88it/s]
# Czas wykonania: 2.4660236835479736 sekund
# Czas wykonania wszystkich algorytmów: 104.41075801849365 sekund
